# %% [markdown]
# # TGA-FTIR hyphenation tool kit

# %% [markdown]
# ##### This Notebook can be used to create cali.xlsx containing calibration data obtained by several calcium oxalat monohydrate measurements.

# %%
import TGA_FTIR_tools as tir
# Out:
# No dir_home path was supplied in settings.ini. dir_home was set to 'C:/Users/ddittman/Desktop/Paper - Aktivkohlecharakterisierung/06_TGA-FTIR/TGA-FTIR-hyphenation-tool-kit-master_calibration'
#
# No valid dir_data path was supplied in 'settings.ini'.
# Supply directory of Data:C:\Users\ddittman\Desktop\2020-09-14_SPEKTRO_TGA-FTIR
# No calibration data found. To obtain quantitative IR data supply an 'Calibration' folder in the home directory containing cali.xlsx or run TGA_FTIR_tools.calibrate(mode='recalibrate')!

# %% [markdown]
# ### Run automated calibration

# %%
tir.calibrate(mode='recalibrate', method='co_oxi_iter', plot=False)
# Out:
# Calibrating...
# Baseline found for CO, CO2, H2O
# ----------------------------------------------------
# ls_6.6_18358_012
# Baseline found for CO, CO2, H2O
# ----------------------------------------------------
# ls_6.6_18358_013
# Baseline found for CO, CO2, H2O
# ----------------------------------------------------
# ls_6.6_18358_014
# Baseline found for CO, CO2, H2O
# ----------------------------------------------------
# ls_6.6_18358_015
# Baseline found for CO, CO2, H2O
# ----------------------------------------------------
# ls_6.6_18358_016
# Baseline found for CO, CO2, H2O
# ----------------------------------------------------
# ls_6.6_18358_017
# Baseline found for CO, CO2, H2O
# ----------------------------------------------------
# ls_6.6_18358_018
# Baseline found for CO, CO2, H2O
# ----------------------------------------------------
# ls_6.6_18358_019
# Baseline found for CO, CO2, H2O
# ----------------------------------------------------
# ls_6.6_18358_020
# ...

# %% [markdown]
# ### Load calibration data from cali.xlsx and show linear regressions

# %%
tir.calibrate(mode='load', plot = True)
# Out:
# (           slope  intercept   r_value       p_value   std_error
#  CO    435.425642  -0.417216  0.999413  5.470380e-16    4.718884
#  CO2  9144.378095  24.033922  0.998762  2.289272e-14  144.047985
#  H2O    17.169582   0.017487  0.999708  1.664116e-17    0.131185,
#           s_yx      s_x0     x_LOD     x_LOQ
#  CO   0.110127  0.000253  0.000574  0.001722
#  CO2  3.251240  0.000356  0.000792  0.002376
#  H2O  0.003414  0.000199  0.000444  0.001333)
